# %%
import os
import sys

sys.path.append('..')

import numpy as np
import pandas as pd
import scipy.optimize as opt
from pandas import DataFrame

from Constants.constants import Constants
from Constants.parameters import Parameters as parameters
from Utilities import generate_profitability_distribution, get_range, inter_product

# %%
class FirmValue(Constants):
    """
    This function used to find the optimal value of firm value given
    """

    def __init__(self, delta=None, rho=None, mu=None, gamma=None, theta=None, sigma=None, lambda_=None):
        """
        init

        :param delta: depreciation rate.
        :param rho: autocorrelation of profitability shock,
        :param mu: drift of profitability shock
        :param gamma: adjustment cost of investment.
        :param theta: collateral parameter
        :param sigma: std. dev. of profitability shocks,
        :param lambda_: equity issuance cost.
        :return: value function and firm
        """
        self._delta = None
        self._rho = None
        self._mu = None
        self._gamma = None
        self._theta = None
        self._sigma = None
        self._lambda = None
        self._profitability_grid = None
        self._transition_matrix = None
        self._investment_grid = None
        self._debt_grid = None
        self._debt_prime_grid = None

        self._firm_value = None

        # store policy matrix
        self._debt_policy_matrix = None
        self._invest_policy_matrix = None

        self.initialize(delta, rho, mu, gamma, theta, sigma, lambda_)

    def initialize(self, delta=None, rho=None, mu=None, gamma=None, theta=None, sigma=None, lambda_=None):
        self._delta = delta if delta is not None else parameters.delta_
        self._rho = rho if rho is not None else parameters.rho_
        self._mu = mu if mu is not None else parameters.mu_
        self._gamma = gamma if gamma is not None else parameters.gamma_
        self._theta = theta if theta is not None else parameters.theta_
        self._sigma = sigma if sigma is not None else parameters.sigma_
        self._lambda = lambda_ if lambda_ is not None else parameters.lambda_
        self._profitability_grid, self._transition_matrix = generate_profitability_distribution(self._mu, self._rho,
                                                                                                self._sigma, self.Z_NUM)

        self._debt_grid = get_range(-self._theta, self._theta, self.P_NUM)
        self._investment_grid = get_range(self._delta * (2 - np.ceil(self.I_NUM / (2 * self.DELP))),
                                          self._delta * (2 + np.ceil(self.I_NUM / (2 * self.DELP))),
                                          self.I_NUM)
        self._debt_prime_grid = get_range(-self._theta, self._theta, self.P_NEXT_NUM)
        self._firm_value = np.zeros((self.P_NUM, self.Z_NUM))
        self._debt_policy_matrix = np.zeros((self.P_NUM, self.Z_NUM), dtype=int)
        self._invest_policy_matrix = np.zeros((self.P_NUM, self.Z_NUM), dtype=int)

    def optimize(self):
        """
        Optimize model from BKW 2018 crs_toni_v2.f90
        :return: error code list
            0: Succeed
            1: Don't coverage
            2: Too large model difference
        """
        firm_value = self._firm_value.copy()
        all_val = np.zeros((self.P_NUM, self.P_NEXT_NUM, self.I_NUM, self.Z_NUM))
        queue_i = np.zeros((self.P_NEXT_NUM, self.I_NUM, self.Z_NUM))
        payoff = self.get_payoff_matrix()

        for _ in range(self.MAX_ITERATION):
            expected_fv = np.dot(firm_value, self._transition_matrix)
            expected_fv_prime = np.zeros((self.P_NEXT_NUM, self.Z_NUM))
            for ip in range(self.P_NEXT_NUM):
                ipd = int(ip * (self.P_NUM - 1) / (self.P_NEXT_NUM - 1))
                ipu = ipd + 1

                if ipu >= self.P_NUM:
                    ipd = self.P_NUM - 1
                    expected_fv_prime[ip, :] = expected_fv[ipd, :]
                else:
                    frac = (self._debt_grid[ipu] - self._debt_prime_grid[ip]) / (
                                self._debt_grid[ipu] - self._debt_grid[ipd])
                    # print(frac)
                    expected_fv_prime[ip, :] = expected_fv[ipd, :] * frac + expected_fv[ipu, :] * (1 - frac)

            for i in range(self.I_NUM):
                queue_i[:, i, :] = expected_fv_prime * (1 - self._delta + self._investment_grid[i])

            for ip in range(self.P_NUM):
                all_val[ip, :, :, :] = payoff[ip, :, :, :] + self.BETA * queue_i

            firm_value_next = np.max(np.max(all_val, axis=1), axis=1)
            difference = firm_value_next - firm_value
            model_diff = np.max(np.abs(difference))
            if _ % 100 == 0:
                print('Iteration: %d, Model difference: %f' % (_, model_diff))
            if model_diff < self.COVERAGE_THRESHOLD:
                break
            elif model_diff > self.DIFF_MAX_THRESHOLD:
                return 2
                # break

            firm_value = firm_value_next.copy()

        else:
            return 1

        self._firm_value = firm_value.copy()

        for iz in range(self.Z_NUM):
            for ip in range(self.P_NUM):
                current_value_firm = all_val[ip, :, :, iz]
                debt_max_i, invest_max_i = np.unravel_index(np.argmax(current_value_firm, axis=None),
                                                            current_value_firm.shape)
                self._debt_policy_matrix[ip, iz] = debt_max_i
                self._invest_policy_matrix[ip, iz] = invest_max_i
                return 0

    def optimize_terry(self):
        """
        Follow Stephen James Terry. Junior Accounting Theory Workshop, intro to structural estimation, 2018

        :return: same as optimize
        """
        debt_policy_matrix = self._debt_policy_matrix.copy()
        invest_policy_matrix = self._invest_policy_matrix.copy()
        firm_value = self._firm_value.copy()
        firm_value_last = firm_value.copy()

        payoff = self.get_payoff_matrix()

        for _ in range(self.MAX_ITERATION):
            # value function iteration
            for __ in range(self.VALUE_FUNCTION_ITERATION):
                for ip in range(self.P_NUM):
                    for iz in range(self.Z_NUM):
                        invest = self._investment_grid[invest_policy_matrix[ip, iz]]
                        debt_prime = self._debt_prime_grid[debt_policy_matrix[ip, iz]]
                        cfrac, debt_low_i, debt_up_i = inter_product(debt_prime, self._debt_grid)
                        fv_prime = firm_value[debt_low_i, :] * cfrac + firm_value[debt_up_i, :] * (1 - cfrac)
                        current_payoff = payoff[ip, debt_policy_matrix[ip, iz], invest_policy_matrix[ip, iz], iz]
                        firm_value[ip, iz] = current_payoff + self.BETA * np.dot(
                            fv_prime, self._transition_matrix[iz, :]) * (1 - self._delta + invest)

            # update policy matrix
            for ip in range(self.P_NUM):
                for iz in range(self.Z_NUM):
                    firm_value_prob = np.zeros((self.P_NEXT_NUM, self.I_NUM))
                    for ip_prime in range(self.P_NEXT_NUM):
                        for ii in range(self.I_NUM):
                            debt_prime = self._debt_prime_grid[ip_prime]

                            cfrac, debt_low_i, debt_up_i = inter_product(debt_prime, self._debt_grid)
                            fv_prime = firm_value[debt_low_i, :] * cfrac + firm_value[debt_up_i, :] * (1 - cfrac)
                            firm_value_prob[ip_prime, ii] = payoff[ip, ip_prime, ii, iz] + self.BETA * np.dot(
                                fv_prime, self._transition_matrix[iz, :]) * (1 - self._delta + self._investment_grid[
                                ii])

                    debt_max_i, invest_max_i = np.unravel_index(np.argmax(firm_value_prob, axis=None),
                                                                firm_value_prob.shape)
                    debt_policy_matrix[ip, iz] = debt_max_i
                    invest_policy_matrix[ip, iz] = invest_max_i

            # check difference
            value_difference = firm_value - firm_value_last
            diff = np.max(np.abs(value_difference))
            if _ % 10 == 0:
                print('Iteration: %d, Model difference: %f' % (_, diff))
            if diff > self.DIFF_MAX_THRESHOLD:
                return 2
            elif diff < self.COVERAGE_THRESHOLD:
                self._firm_value = firm_value.copy()
                self._debt_policy_matrix = debt_policy_matrix.copy()
                self._invest_policy_matrix = invest_policy_matrix.copy()
                return 0

            firm_value_last = firm_value.copy()

        else:
            # not coverage
            return 1

    def set_model_parameters(self, delta=None, rho=None, mu=None, gamma=None, theta=None, sigma=None, lambda_=None):
        if delta is not None:
            self.set_delta(delta)

        if rho is not None:
            self.set_rho(rho)

        if mu is not None:
            self.set_mu(mu)

        if gamma is not None:
            self.set_gamma(gamma)

        if theta is not None:
            self.set_theta(theta)

        if sigma is not None:
            self.set_sigma(sigma)

        if lambda_ is not None:
            self.set_lambda(lambda_)

    def set_delta(self, delta):
        self._delta = delta

    def set_rho(self, rho):
        self._rho = rho

    def set_mu(self, mu):
        self._mu = mu

    def set_gamma(self, gamma):
        self._gamma = gamma

    def set_theta(self, theta):
        self._theta = theta

    def set_sigma(self, sigma):
        self._sigma = sigma

    def set_lambda(self, lambda_):
        self._lambda = lambda_

    def get_payoff_matrix(self):
        payoff = np.zeros((self.P_NUM, self.P_NEXT_NUM, self.I_NUM, self.Z_NUM))

        for ip in range(self.P_NUM):
            for ip_prime in range(self.P_NEXT_NUM):
                for ii in range(self.I_NUM):
                    for iz in range(self.Z_NUM):
                        payoff[ip, ip_prime, ii, iz] = self.get_payoff(
                            self._profitability_grid[iz], self._investment_grid[ii], self._debt_grid[ip],
                            self._debt_prime_grid[ip_prime])
        return payoff

    def get_payoff(self, profitability, investment, debt, next_debt):
        payoff = profitability - investment - 0.5 * self._gamma * (investment ** 2) - debt * (1 + self.RF) \
                 + next_debt * (1 - self._delta + investment)

        if payoff < 0:
            payoff *= (1 + self._lambda)

        return payoff

    def simulate_model(self, years, firms):
        """
        simulate model
        :param years: number of year
        :param firms: number of firms
        :return: simulated model vectors
            firm_id
            year
            value
            profitability
            debt
            investment
            payoff
        """
        # initialize
        init_value = np.random.random(firms)
        profit_index = [int(i * self.Z_NUM) for i in init_value]
        debt_index = [int(i * self.P_NUM) for i in init_value]
        value_array = [self._firm_value[debt_index[i], profit_index[i]] for i in range(firms)]
        investment_array = [self._investment_grid[self._invest_policy_matrix[debt_index[i], profit_index[i]]] for i in
                            range(firms)]
        debt_array = [self._debt_grid[int(i * self.P_NUM)] for i in init_value]
        trans_cdf = self._transition_matrix.copy()

        for i in range(self.Z_NUM - 2):
            trans_cdf[:, i + 1] += trans_cdf[:, i]

        trans_cdf[:, self.Z_NUM - 1] = 1

        # run simulation
        simulated_data_list = list()
        for year_i in range(years):
            simulated_data = DataFrame(
                columns=['value', 'profitability', 'debt', 'investment', 'payoff', 'debt_prime'],
                index=list(range(firms)))

            simulated_data.loc[:, 'profitability'] = self._profitability_grid[profit_index]
            simulated_data.loc[:, 'debt'] = debt_array
            simulated_data.loc[:, 'value'] = value_array

            # get next period profitability
            next_shock = np.random.random(firms)
            for i in range(firms):
                # save current data
                profitability = simulated_data.loc[i, 'profitability']
                debt = simulated_data.loc[i, 'debt']

                # determine next period values
                cfrac, low_index, up_index = inter_product(debt_array[i], self._debt_grid)
                profit_index[i] = len(trans_cdf[profit_index[i]][trans_cdf[profit_index[i]] < next_shock[i]])
                debt_prime_up = self._debt_prime_grid[self._debt_policy_matrix[up_index, profit_index[i]]]
                debt_prime_low = self._debt_prime_grid[self._debt_policy_matrix[low_index, profit_index[i]]]
                invest_prime_up = self._investment_grid[self._invest_policy_matrix[up_index, profit_index[i]]]
                invest_prime_low = self._investment_grid[self._invest_policy_matrix[low_index, profit_index[i]]]

                debt_array[i] = cfrac * debt_prime_low + (1 - cfrac) * debt_prime_up
                value_array[i] = cfrac * self._firm_value[low_index, profit_index[i]] + (1 - cfrac) \
                                 * self._firm_value[up_index, profit_index[i]]
                investment_array[i] = cfrac * invest_prime_low + (1 - cfrac) * invest_prime_up

                simulated_data.loc[i, 'payoff'] = self.get_payoff(profitability, investment_array[i], debt,
                                                                  debt_array[i])

            simulated_data.loc[:, 'year'] = year_i
            simulated_data.loc[:, 'firm_id'] = list(range(firms))
            simulated_data.loc[:, 'debt_prime'] = debt_array
            simulated_data.loc[:, 'investment'] = investment_array
            simulated_data_list.append(simulated_data)

        return pd.concat(simulated_data_list, ignore_index=True, sort=False)

# %%
cov_matrix_list = ''' 1.109708117	-0.005453733	0.057355899	0.004006414	-0.011096374	-0.007197551	0.005645	-0.009212411
-0.005453733	0.017286135	-0.000443486	0.000297896	-0.002858936	0.001057859	-0.003144528	0.001290623
0.057355899	-0.000443486	0.050829381	0.003399744	-0.005320978	0.000654373	0.025193349	0.000681779
0.004006414	0.000297896	0.003399744	0.000421314	-0.000845842	0.00012831	0.000718566	0.000148138
-0.011096374	-0.002858936	-0.005320978	-0.000845842	0.033832022	-0.003816715	0.037418057	-0.001367266
-0.007197551	0.001057859	0.000654373	0.00012831	-0.003816715	0.001233236	-0.002444826	0.000397526
0.005645	-0.003144528	0.025193349	0.000718566	0.037418057	-0.002444826	0.121059595	-0.000328985
-0.009212411	0.001290623	0.000681779	0.000148138	-0.001367266	0.000397526	-0.000328985	0.001289656'''.split('\n')
cov_matrix = np.zeros((8, 8))

for i, line in enumerate(cov_matrix_list):
    for j, cell in enumerate(line.split('\t')):
        cov_matrix[i, j] = float(cell)

# %%
def get_moments(fv: FirmValue, process_num:int=1):
    """
    Simulate model and return moments
    :param fv: an optimized firm value
    :param process_num: number of multiprocessing number
    :return: a list [mean investment, var investment, mean leverage, var leverage, mean payoff, var payoff,
                     mean profit, var profit]
        0.0768111297195329
        0.0032904184631855
        0.1885677166674841
        0.0285271524764669
        0.0012114713963756
        0.0058249053810193
        0.1421154126428439
        0.0080642043112130

    """
    if process_num > 1:
        firm_num = FirmValue.N_FIRMS // process_num
        firm_num_reminder = firm_num % process_num
        firm_num_list = [firm_num for _ in range(process_num)]

        for i in range(firm_num_reminder):
            firm_num_list[i] += 1

        pool = pathos.multiprocessing.ProcessPool(process_num)
        simulated_result = pool.map(lambda x: fv.simulate_model(FirmValue.N_YEARS, x), firm_num_list)
        simulated_result2 = list()

        for i, result_df in enumerate(simulated_result):
            result_df.loc[:, 'firm_id'] = result_df['firm_id'].apply(lambda x: '{}_{}'.format(i, x))
            simulated_result2.append(result_df)
        sim_data: DataFrame = pd.concat(simulated_result2, ignore_index=True, sort=False)

    else:
        sim_data: DataFrame = fv.simulate_model(years=FirmValue.N_YEARS, firms=9000)
    sim_data_valid: DataFrame = sim_data.iloc[-8:].copy()
    result_series = np.zeros(8)
    mean_data = sim_data_valid.mean()
    var_data = sim_data_valid.var()
    result_series[0] = mean_data['debt']
    result_series[1] = var_data['debt']
    result_series[1] = mean_data['investment']
    result_series[2] = var_data['investment']
    result_series[4] = mean_data['payoff']
    result_series[5] = var_data['payoff']
    result_series[6] = mean_data['profitability']
    result_series[7] = var_data['profitability']

    return result_series


def get_moments_error(data_mom, sim_mom, weighted_matrix):
    err_mom = data_mom - sim_mom
    crit_val = err_mom.T @ weighted_matrix @ err_mom
    return crit_val


def criterion(params, *args):
    mu, rho, sigma, delta, gamma, theta, lambda_ = params
    process_num: int = args[0]
    fv = FirmValue(delta=delta, mu=mu, rho=rho, sigma=sigma, theta=theta, lambda_=lambda_, gamma=gamma)
    error_code = fv.optimize_terry()
    if error_code != 0:
        return 1e18
    data_moments = np.array([0.1885677166674841, 0.0285271524764669, 0.0768111297195329, 0.0032904184631855, 
                             0.0012114713963756, 0.0058249053810193, 0.1421154126428439, 0.0080642043112130])
    sim_moments = get_moments(fv, process_num)
    moments_error = get_moments_error(data_moments, sim_moments, cov_matrix)
    print('Moments errors are:', moments_error)
    return moments_error

# %% [markdown]
# Result for np.eye as weighted matrix

# %%
    params_init_1 = np.array([-2.2067, 0.8349, 0.3594, 0.044, 29.966, 0.381, 0.182])
    results1_1 = opt.minimize(criterion, params_init_1, args=(1,), method='L-BFGS-B',
                              options={'eps': 1e-1, 'gtol': 1e-3},
                              bounds=(
                                  (-6.5, -0.5), (0.3, 0.9), (0.05, 0.6), (0.01, 0.2), (3, 30), (0.1, 0.7),
                                  (0.01, 0.25)))
    print(results1_1)
# Out:
# Iteration: 0, Model difference: 3.130944
# Iteration: 10, Model difference: 0.308268
# Iteration: 0, Model difference: 3.111329
# Iteration: 0, Model difference: 3.077723
# Iteration: 10, Model difference: 0.000034
# Moments errors are: 0.01882599284924767
# Iteration: 0, Model difference: 3.156272
# Iteration: 0, Model difference: 12.528848
# Moments errors are: 0.049580405144583166
# Iteration: 0, Model difference: 3.118188
# Iteration: 10, Model difference: 0.508150
# Iteration: 0, Model difference: 3.252004
# Iteration: 10, Model difference: 0.436676
# Iteration: 0, Model difference: 2.866059
# Iteration: 10, Model difference: 70537.613236
# Iteration: 0, Model difference: 17.736477
# Moments errors are: 0.0390004950176372
# Iteration: 0, Model difference: 17.733129
# Moments errors are: 0.04059442906935675
# Iteration: 0, Model difference: 17.735611
# Moments errors are: 0.034930581915394554
# Iteration: 0, Model difference: 17.746830
# Moments errors are: 0.031836888904092836
# Iteration: 0, Model difference: 8.370495
# Moments errors are: 0.05158008076935219
# Iteration: 0, Model difference: 17.675313
# Moments errors are: 0.038819243755396374
# Iteration: 0, Model difference: 17.856975
# Moments errors are: 0.05197143914937946
# Iteration: 0, Model difference: 16.235929
# Moments errors are: 0.03933689079931047
# Iteration: 0, Model difference: 17.636527
# Moments errors are: 0.024939808860973925
# Iteration: 0, Model difference: 17.633950
# Moments errors are: 0.023152413801719115
# Iteration: 0, Model difference: 17.635640
# Moments errors are: 0.02242863572781118
# Iteration: 0, Model difference: 17.645080
# Moments errors are: 0.024937337136530437
# Iteration: 0, Model difference: 8.249401
# Moments errors are: 0.024582535979943584
# Iteration: 0, Model difference: 17.575188
# Moments errors are: 0.02197585089910109
# Iteration: 0, Model difference: 17.757367
# Moments errors are: 0.029838439814506318
# Iteration: 0, Model difference: 16.148669
# Moments errors are: 0.022037358064856086
# Iteration: 0, Model difference: 14.367702
# Moments errors are: 0.023858485278467297
# Iteration: 0, Model difference: 14.364378
# Moments errors are: 0.022790029662086805
# Iteration: 0, Model difference: 14.368441
# Moments errors are: 0.02200485406186075
# Iteration: 0, Model difference: 14.375984
# Moments errors are: 0.024398839132783085
# Iteration: 0, Model difference: 5.101480
# Moments errors are: 0.014998455109244387
# Iteration: 0, Model difference: 14.316820
# Moments errors are: 0.022484463024775785
# Iteration: 0, Model difference: 14.486529
# Moments errors are: 0.020433843001646027
# Iteration: 0, Model difference: 13.134769
# Moments errors are: 0.02920162974676506
# Iteration: 0, Model difference: 11.378510
# Moments errors are: 0.03555330578475105
# Iteration: 0, Model difference: 11.373311
# Moments errors are: 0.029986087686191647
# Iteration: 0, Model difference: 11.381845
# Moments errors are: 0.025463539863605177
# Iteration: 0, Model difference: 11.387390
# Moments errors are: 0.041508019577051164
# Iteration: 0, Model difference: 1.830283
# Iteration: 0, Model difference: 11.337401
# Moments errors are: 0.03645416526238212
# Iteration: 0, Model difference: 11.498875
# Moments errors are: 0.021689401462438192
# Iteration: 0, Model difference: 10.414172
# Moments errors are: 0.028083246843904244
# Iteration: 0, Model difference: 13.217099
# Moments errors are: 0.03487208722343645
# Iteration: 0, Model difference: 13.213169
# Moments errors are: 0.024815726189964273
# Iteration: 0, Model difference: 13.218703
# Moments errors are: 0.027171991228379076
# Iteration: 0, Model difference: 13.225624
# Moments errors are: 0.044519201509946524
# Iteration: 0, Model difference: 3.867857
# Moments errors are: 0.02216012963689493
# Iteration: 0, Model difference: 13.169981
# Moments errors are: 0.024065327096092343
# Iteration: 0, Model difference: 13.336521
# Moments errors are: 0.03153475967628491
# Iteration: 0, Model difference: 12.088394
# Moments errors are: 0.02827956518663946
# Iteration: 0, Model difference: 14.347720
# Moments errors are: 0.02190004905066559
# Iteration: 0, Model difference: 14.344386
# Moments errors are: 0.02399009069198081
# Iteration: 0, Model difference: 14.348474
# Moments errors are: 0.02287542987379983
# Iteration: 0, Model difference: 14.356007
# Moments errors are: 0.02364643439621993
# Iteration: 0, Model difference: 5.080197
# Moments errors are: 0.021095209809891723
# Iteration: 0, Model difference: 14.296904
# Moments errors are: 0.024025640405985
# Iteration: 0, Model difference: 14.466558
# Moments errors are: 0.023658215434828468
# Iteration: 0, Model difference: 13.116607
# Moments errors are: 0.023931475215835493
# Iteration: 0, Model difference: 14.280079
# Moments errors are: 0.021920091667601258
# Iteration: 0, Model difference: 14.276729
# Moments errors are: 0.0280364156050953
# Iteration: 0, Model difference: 14.280901
# Moments errors are: 0.026957344340404296
# Iteration: 0, Model difference: 14.288328
# Moments errors are: 0.049729097253658774
# Iteration: 0, Model difference: 4.986556
# Moments errors are: 0.024044646836611294
# Iteration: 0, Model difference: 14.229464
# Moments errors are: 0.021728289350551475
# Iteration: 0, Model difference: 14.399220
# Moments errors are: 0.021984486550273984
# Iteration: 0, Model difference: 13.057880
# Moments errors are: 0.024112011092631516
# Iteration: 0, Model difference: 14.312274
# Moments errors are: 0.03154701760855491
# Iteration: 0, Model difference: 14.308933
# Moments errors are: 0.03197655129588632
# Iteration: 0, Model difference: 14.313064
# Moments errors are: 0.022239810961471967
# Iteration: 0, Model difference: 14.320542
# Moments errors are: 0.023405486307352466
# Iteration: 0, Model difference: 5.031114
# Moments errors are: 0.02006707167630172
# Iteration: 0, Model difference: 14.261564
# Moments errors are: 0.026056366268172523
# Iteration: 0, Model difference: 14.431272
# Moments errors are: 0.01917258802190118
# Iteration: 0, Model difference: 13.085841
# Moments errors are: 0.02543795116670567
# Iteration: 0, Model difference: 14.347690
# Moments errors are: 0.022086777281159136
# Iteration: 0, Model difference: 14.344356
# Moments errors are: 0.029945036792797364
# Iteration: 0, Model difference: 14.348443
# Moments errors are: 0.0447792926167421
# Iteration: 0, Model difference: 14.355976
# Moments errors are: 0.02240709999377495
# Iteration: 0, Model difference: 5.080155
# Moments errors are: 0.017168565623769026
# Iteration: 0, Model difference: 14.296874
# Moments errors are: 0.029711889382528008
# Iteration: 0, Model difference: 14.466528
# Moments errors are: 0.019009436275427526
# Iteration: 0, Model difference: 13.116581
# Moments errors are: 0.03377310262422992
# Iteration: 0, Model difference: 14.347720
# Moments errors are: 0.02199756262920568
# Iteration: 0, Model difference: 14.344386
# Moments errors are: 0.030561653688004165

# %%
    params_init_1 = np.array([-2.2067, 0.8349, 0.3594, 0.0449, 29.9661, 0.3816, 0.1829])
    results1_1 = opt.dual_annealing(criterion, args=(1,), x0=params_init_1,
                              bounds=(
                                  (-3.5, -1.5), (0.8, 0.9), (0.3, 0.4), (0.01, 0.05), (25, 30), (0.1, 0.4),
                                  (0.01, 0.25)))
    print(results1_1)
# Out:
# Iteration: 0, Model difference: 2.108681
# Iteration: 0, Model difference: 2.548648
# Iteration: 0, Model difference: 2.430482
# Moments errors are: 0.001761823992359608
# Iteration: 0, Model difference: 2.194735
# Iteration: 0, Model difference: 2.253752
# Moments errors are: 0.03663644568876667
# Iteration: 0, Model difference: 0.926258
# Iteration: 10, Model difference: 0.001140
# Moments errors are: 0.0064888481683688555
# Iteration: 0, Model difference: 1.684006
# Iteration: 0, Model difference: 1.606390
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0006519275233890279
# Iteration: 0, Model difference: 2.374607
# Iteration: 10, Model difference: 0.002030
# Moments errors are: 0.003815995344177767
# Iteration: 0, Model difference: 2.360482
# Iteration: 10, Model difference: 0.000028
# Moments errors are: 0.0008622770467347481
# Iteration: 0, Model difference: 1.451297
# Iteration: 0, Model difference: 1.943349
# Iteration: 10, Model difference: 4.037827
# Iteration: 0, Model difference: 2.508554
# Iteration: 10, Model difference: 0.000166
# Moments errors are: 0.01069535755607452
# Iteration: 0, Model difference: 2.628248
# Iteration: 10, Model difference: 0.000033
# Moments errors are: 0.0017022191146838215
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0010313467377779414
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0008274610961045787
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0011249832240510902
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0007328945132625334
# Iteration: 0, Model difference: 2.361357
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0016006747088008286
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.00132063130266729
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0009831117215259233
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0012081689217581103
# Iteration: 0, Model difference: 5.154225
# Iteration: 0, Model difference: 5.154225
# Iteration: 0, Model difference: 5.154225
# Iteration: 0, Model difference: 5.154224
# Iteration: 0, Model difference: 5.154222
# Iteration: 0, Model difference: 5.154225
# Iteration: 0, Model difference: 5.154225
# Iteration: 0, Model difference: 5.154225
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.000909090476635472
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0006964622458872347
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0016018238339275293
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0012973001444830379
# Iteration: 0, Model difference: 2.361357
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0007700008941403892
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.001557263940732396
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0014938372604356635
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0012893988229793322
# Iteration: 0, Model difference: 1.252300
# Iteration: 0, Model difference: 1.252300
# Iteration: 0, Model difference: 1.252300
# Iteration: 0, Model difference: 1.252300
# Iteration: 0, Model difference: 1.252299
# Iteration: 0, Model difference: 1.252300
# Iteration: 0, Model difference: 1.252300
# Iteration: 0, Model difference: 1.252300
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0015689955202930219
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0013329869352629547
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0012409174114832982
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0022960088372776946
# Iteration: 0, Model difference: 2.361357
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0015999426438441304
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0008217921308303791
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0008918344512435621
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0007334475412165877
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0007377911153930814
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0011912476970339326
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0010978259608217676
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.001870633532941323
# Iteration: 0, Model difference: 2.361357
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0013465479742382571
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0013548282322347989
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0009909169424708719
# Iteration: 0, Model difference: 2.361356
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0006682281730452065
# Iteration: 0, Model difference: 0.779808
# Moments errors are: 0.011733560211701284
# Iteration: 0, Model difference: 0.779808
# Moments errors are: 0.01150711483081192
# Iteration: 0, Model difference: 0.779808
# Moments errors are: 0.011266869950831392
# Iteration: 0, Model difference: 0.779808
# Moments errors are: 0.011624435980480817
# Iteration: 0, Model difference: 0.779807
# Moments errors are: 0.011691924393549567
# Iteration: 0, Model difference: 0.779808
# Moments errors are: 0.011485341416514222
# Iteration: 0, Model difference: 0.779808
# Moments errors are: 0.011409150146914532
# Iteration: 0, Model difference: 0.779808
# Moments errors are: 0.01139868228710238
# Iteration: 0, Model difference: 1.186351
# Moments errors are: 0.002677808841095943
# Iteration: 0, Model difference: 1.186351
# Moments errors are: 0.003094009030495149
# Iteration: 0, Model difference: 1.186351
# Moments errors are: 0.0032376663897255593
# Iteration: 0, Model difference: 1.186351
# Moments errors are: 0.002864233027984423
# Iteration: 0, Model difference: 1.186352
# Moments errors are: 0.0027758854904627542
# Iteration: 0, Model difference: 1.186351
# Moments errors are: 0.0033535904808868764
# Iteration: 0, Model difference: 1.186351
# Moments errors are: 0.0026047542503364563
# Iteration: 0, Model difference: 1.186351
# Moments errors are: 0.003122240062703752
# Iteration: 0, Model difference: 2.113511
# Moments errors are: 0.0018025614394372982
# Iteration: 0, Model difference: 2.113511
# Moments errors are: 0.0008755525496464587
# Iteration: 0, Model difference: 2.113511
# Moments errors are: 0.0013597991989122038
# Iteration: 0, Model difference: 2.113511
# Moments errors are: 0.0008381525525153919
# Iteration: 0, Model difference: 2.113512
# Moments errors are: 0.001185934640283438
# Iteration: 0, Model difference: 2.113511
# Moments errors are: 0.0006459203167267365
# Iteration: 0, Model difference: 2.113511
# Moments errors are: 0.0014753837886776113
# Iteration: 0, Model difference: 2.113511
# Moments errors are: 0.0014994215389050685
# Iteration: 0, Model difference: 2.228674
# Moments errors are: 0.0012040855739008473
# Iteration: 0, Model difference: 2.228674
# Moments errors are: 0.0015759025660808668
# Iteration: 0, Model difference: 2.228674
# Moments errors are: 0.0008580347368154152
# Iteration: 0, Model difference: 2.228674
# Moments errors are: 0.0005878278288555126
# Iteration: 0, Model difference: 2.228674
# Moments errors are: 0.0008921507778102685
# Iteration: 0, Model difference: 2.228674
# Moments errors are: 0.0006868818863804406
# Iteration: 0, Model difference: 2.228674
# Moments errors are: 0.0008538280855897667
# Iteration: 0, Model difference: 2.228674
# Moments errors are: 0.0006519611822694925
# Iteration: 0, Model difference: 2.303495
# Iteration: 10, Model difference: 0.000020
# Moments errors are: 0.0013496564249757064
# Iteration: 0, Model difference: 2.303495
# Iteration: 10, Model difference: 0.000020
# Moments errors are: 0.001195364224218154
# Iteration: 0, Model difference: 2.303495
# Iteration: 10, Model difference: 0.000020
# Moments errors are: 0.000925444394992513
# Iteration: 0, Model difference: 2.303495
# Iteration: 10, Model difference: 0.000020
# Moments errors are: 0.0014877214848888157
# Iteration: 0, Model difference: 2.303495
# Iteration: 10, Model difference: 0.000020
# Moments errors are: 0.0012006970363758467
# Iteration: 0, Model difference: 2.303495
# Iteration: 10, Model difference: 0.000020
# Moments errors are: 0.0017910109226077463
# Iteration: 0, Model difference: 2.303495
# Iteration: 10, Model difference: 0.000020
# Moments errors are: 0.0012369650492336957
# Iteration: 0, Model difference: 2.303495
# Iteration: 10, Model difference: 0.000020
# Moments errors are: 0.0015463961353278778
# Iteration: 0, Model difference: 2.346391
# Iteration: 10, Model difference: 0.000031
# Moments errors are: 0.0029851294388444785
# Iteration: 0, Model difference: 2.346391
# Iteration: 10, Model difference: 0.000031
# Moments errors are: 0.0012032498924768628
# Iteration: 0, Model difference: 2.346391
# Iteration: 10, Model difference: 0.000031
# Moments errors are: 0.0007531306014928315
# Iteration: 0, Model difference: 2.346391
# Iteration: 10, Model difference: 0.000031
# Moments errors are: 0.0011372071462517814
# Iteration: 0, Model difference: 2.346392
# Iteration: 10, Model difference: 0.000031
# Moments errors are: 0.0009001288274446868
# Iteration: 0, Model difference: 2.346391
# Iteration: 10, Model difference: 0.000031
# Moments errors are: 0.0007796028980981124
# Iteration: 0, Model difference: 2.346391
# Iteration: 10, Model difference: 0.000031
# Moments errors are: 0.001424039012179325
# Iteration: 0, Model difference: 2.346391
# Iteration: 10, Model difference: 0.000031
# Moments errors are: 0.0015949981910004522
# Iteration: 0, Model difference: 2.352997
# Iteration: 10, Model difference: 0.000035
# Moments errors are: 0.0028484095602273147
# Iteration: 0, Model difference: 2.352997
# Iteration: 10, Model difference: 0.000035
# Moments errors are: 0.0020621805779082437
# Iteration: 0, Model difference: 2.352997
# Iteration: 10, Model difference: 0.000035
# Moments errors are: 0.0008402996095806629
# Iteration: 0, Model difference: 2.352997
# Iteration: 10, Model difference: 0.000035
# Moments errors are: 0.0009966652160942567
# Iteration: 0, Model difference: 2.352998
# Iteration: 10, Model difference: 0.000035
# Moments errors are: 0.0010388858250322934
# Iteration: 0, Model difference: 2.352997
# Iteration: 10, Model difference: 0.000035
# Moments errors are: 0.0009959007814485375
# Iteration: 0, Model difference: 2.352997
# Iteration: 10, Model difference: 0.000035
# Moments errors are: 0.0014910047778242718
# Iteration: 0, Model difference: 2.352997
# Iteration: 10, Model difference: 0.000035
# Moments errors are: 0.0014859625781518363
# Iteration: 0, Model difference: 2.356749
# Iteration: 10, Model difference: 0.000032
# Moments errors are: 0.0009464824379428393
# Iteration: 0, Model difference: 2.356749
# Iteration: 10, Model difference: 0.000032
# Moments errors are: 0.00238045353694008
# Iteration: 0, Model difference: 2.356749
# Iteration: 10, Model difference: 0.000032
# Moments errors are: 0.0005616624884590164
# Iteration: 0, Model difference: 2.356749
# Iteration: 10, Model difference: 0.000032
# Moments errors are: 0.0017648303528474798
# Iteration: 0, Model difference: 2.356750
# Iteration: 10, Model difference: 0.000032
# Moments errors are: 0.0007733230935017069
# Iteration: 0, Model difference: 2.356749
# Iteration: 10, Model difference: 0.000032
# Moments errors are: 0.002512820965445565
# Iteration: 0, Model difference: 2.356749
# Iteration: 10, Model difference: 0.000032
# Moments errors are: 0.001092201687618378
# Iteration: 0, Model difference: 2.356749
# Iteration: 10, Model difference: 0.000032
# Moments errors are: 0.001394048337819166
# Iteration: 0, Model difference: 2.360756
# Iteration: 10, Model difference: 0.000025
# Moments errors are: 0.0010949751991137105
# Iteration: 0, Model difference: 2.360756
# Iteration: 10, Model difference: 0.000025
# Moments errors are: 0.0025551923521106436
# Iteration: 0, Model difference: 2.360756
# Iteration: 10, Model difference: 0.000025
# Moments errors are: 0.001299719761530149
# Iteration: 0, Model difference: 2.360756
# Iteration: 10, Model difference: 0.000025
# Moments errors are: 0.001040921342621469
# Iteration: 0, Model difference: 2.360757
# Iteration: 10, Model difference: 0.000025
# Moments errors are: 0.0010245550178254374
# Iteration: 0, Model difference: 2.360756
# Iteration: 10, Model difference: 0.000025
# Moments errors are: 0.0014235129400520675
# Iteration: 0, Model difference: 2.360756
# Iteration: 10, Model difference: 0.000025
# Moments errors are: 0.0015558230299324285
# Iteration: 0, Model difference: 2.360756
# Iteration: 10, Model difference: 0.000025
# Moments errors are: 0.001130339068956307
# Iteration: 0, Model difference: 2.361224
# Iteration: 10, Model difference: 0.000028
# Moments errors are: 0.0013208636505641941
# Iteration: 0, Model difference: 2.361224
# Iteration: 10, Model difference: 0.000028
# Moments errors are: 0.0009388848316077612
# Iteration: 0, Model difference: 2.361224
# Iteration: 10, Model difference: 0.000028
# Moments errors are: 0.000983991403125007
# Iteration: 0, Model difference: 2.361224
# Iteration: 10, Model difference: 0.000028
# Moments errors are: 0.0025842489478736692
# Iteration: 0, Model difference: 2.361225
# Iteration: 10, Model difference: 0.000028
# Moments errors are: 0.0011065839984188029
# Iteration: 0, Model difference: 2.361224
# Iteration: 10, Model difference: 0.000028
# Moments errors are: 0.001583277980966597
# Iteration: 0, Model difference: 2.361224
# Iteration: 10, Model difference: 0.000028
# Moments errors are: 0.0008745542953462364
# Iteration: 0, Model difference: 2.361225
# Iteration: 10, Model difference: 0.000028
# Moments errors are: 0.0006341455053374092
# Iteration: 0, Model difference: 2.361318
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0021605959080239017
# Iteration: 0, Model difference: 2.361318
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0010710398809312205
# Iteration: 0, Model difference: 2.361318
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0008915003945930758
# Iteration: 0, Model difference: 2.361318
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0011260536511157717
# Iteration: 0, Model difference: 2.361319
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0028049261943123172
# Iteration: 0, Model difference: 2.361318
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0009924435210886889
# Iteration: 0, Model difference: 2.361318
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.001554916212252198
# Iteration: 0, Model difference: 2.361318
# Iteration: 10, Model difference: 0.000027
# Moments errors are: 0.0010023327309265672
# Iteration: 0, Model difference: 2.361336

# %%
results1_1

# %% [markdown]
# Result for cov matrix in BKW 2018 as weighted matrix

# %%
    params_init_1 = np.array([-2.2067, 0.8349, 0.3594, 0.044, 29.966, 0.381, 0.182])
    results1_2 = opt.minimize(criterion, params_init_1, args=(1,), method='L-BFGS-B',
                              options={'eps': 1e-1, 'gtol': 1e-3},
                              bounds=(
                                  (-6.5, -0.5), (0.3, 0.9), (0.05, 0.6), (0.01, 0.2), (3, 30), (0.1, 0.7),
                                  (0.01, 0.25)))
    print(results1_2)
# Out:
# Iteration: 0, Model difference: 3.130944
# Iteration: 10, Model difference: 0.308268
# Iteration: 0, Model difference: 3.111329
# Iteration: 0, Model difference: 3.077723
# Iteration: 10, Model difference: 0.000034
# Moments errors are: 0.016771672949390245
# Iteration: 0, Model difference: 3.156272
# Iteration: 0, Model difference: 12.528848
# Moments errors are: 0.031018880582208103
# Iteration: 0, Model difference: 3.118188
# Iteration: 10, Model difference: 0.508150
# Iteration: 0, Model difference: 3.252004
# Iteration: 10, Model difference: 0.436676
# Iteration: 0, Model difference: 2.866059
# Iteration: 10, Model difference: 70537.613236
# Iteration: 0, Model difference: 17.736477
# Moments errors are: 0.024313302564696448
# Iteration: 0, Model difference: 17.733129
# Moments errors are: 0.027192608487342486
# Iteration: 0, Model difference: 17.735611
# Moments errors are: 0.02233566741017792
# Iteration: 0, Model difference: 17.746830
# Moments errors are: 0.019846782532072397
# Iteration: 0, Model difference: 8.370495
# Moments errors are: 0.03984752005318862
# Iteration: 0, Model difference: 17.675313
# Moments errors are: 0.02474482520548599
# Iteration: 0, Model difference: 17.856975
# Moments errors are: 0.03796250123408076
# Iteration: 0, Model difference: 16.235929
# Moments errors are: 0.027119335499358913
# Iteration: 0, Model difference: 17.997369
# Moments errors are: 0.003646705740866651
# Iteration: 0, Model difference: 17.994520
# Moments errors are: 0.003557670007824712
# Iteration: 0, Model difference: 17.996436
# Moments errors are: 0.0037002336755517944
# Iteration: 0, Model difference: 18.006632
# Moments errors are: 0.0018666442119355249
# Iteration: 0, Model difference: 8.411757
# Moments errors are: 0.003593349546429101
# Iteration: 0, Model difference: 17.934752
# Moments errors are: 0.0036163827574619
# Iteration: 0, Model difference: 18.120727
# Moments errors are: 0.015824697669147708
# Iteration: 0, Model difference: 16.510057
# Moments errors are: 0.003614694170092675
# Iteration: 0, Model difference: 16.635493
# Moments errors are: 0.010453793178438637
# Iteration: 0, Model difference: 16.632545
# Moments errors are: 0.011229496852932636
# Iteration: 0, Model difference: 16.635184
# Moments errors are: 0.010672685862150436
# Iteration: 0, Model difference: 16.644098
# Moments errors are: 0.010457503179861074
# Iteration: 0, Model difference: 6.822585
# Moments errors are: 0.010338721232395022
# Iteration: 0, Model difference: 16.576768
# Moments errors are: 0.010611094678070376
# Iteration: 0, Model difference: 16.761560
# Moments errors are: 0.0007494285662727711
# Iteration: 0, Model difference: 15.290109
# Moments errors are: 0.010477024676306736
# Iteration: 0, Model difference: 17.661466
# Moments errors are: 0.0009069351148748635
# Iteration: 0, Model difference: 17.658603
# Moments errors are: 0.0009255317495038039
# Iteration: 0, Model difference: 17.660671
# Moments errors are: 0.0009167773154427081
# Iteration: 0, Model difference: 17.670556
# Moments errors are: 0.001370593918267787
# Iteration: 0, Model difference: 8.019360
# Moments errors are: 0.0010781961100814095
# Iteration: 0, Model difference: 17.599808
# Moments errors are: 0.0009777356168218702
# Iteration: 0, Model difference: 17.785506
# Moments errors are: 0.008890025464449341
# Iteration: 0, Model difference: 16.209900
# Moments errors are: 0.001312621445412219
# Iteration: 0, Model difference: 17.357527
# Moments errors are: 0.005014634997266813
# Iteration: 0, Model difference: 17.354348
# Moments errors are: 0.006100129996878149
# Iteration: 0, Model difference: 17.357068
# Moments errors are: 0.004937537475240402
# Iteration: 0, Model difference: 17.366916
# Moments errors are: 0.004962741174367422
# Iteration: 0, Model difference: 7.545436
# Moments errors are: 0.004939121181698079
# Iteration: 0, Model difference: 17.296516
# Moments errors are: 0.0051013140517571255
# Iteration: 0, Model difference: 17.483681
# Moments errors are: 0.0023274744890422966
# Iteration: 0, Model difference: 15.954790
# Moments errors are: 0.0049734730208336846
# Iteration: 0, Model difference: 17.615403
# Moments errors are: 0.0006992091802093569
# Iteration: 0, Model difference: 17.612491
# Moments errors are: 0.0007914495298143418
# Iteration: 0, Model difference: 17.614660
# Moments errors are: 0.000742887072827401
# Iteration: 0, Model difference: 17.624538
# Moments errors are: 0.001020313963832678
# Iteration: 0, Model difference: 7.946838
# Moments errors are: 0.000775014994210511
# Iteration: 0, Model difference: 17.553842
# Moments errors are: 0.0007359866124562664
# Iteration: 0, Model difference: 17.739773
# Moments errors are: 0.008277879169351667
# Iteration: 0, Model difference: 16.171451
# Moments errors are: 0.0007630903844492603
# Iteration: 0, Model difference: 17.446831
# Moments errors are: 0.002453157200080605
# Iteration: 0, Model difference: 17.443744
# Moments errors are: 0.002494761129810135
# Iteration: 0, Model difference: 17.446275
# Moments errors are: 0.002557494282106491
# Iteration: 0, Model difference: 17.456133
# Moments errors are: 0.002551006987764855
# Iteration: 0, Model difference: 7.683605
# Moments errors are: 0.002496038365605277
# Iteration: 0, Model difference: 17.385629
# Moments errors are: 0.0025420113331152067
# Iteration: 0, Model difference: 17.572378
# Moments errors are: 0.004705737443806464
# Iteration: 0, Model difference: 16.030080
# Moments errors are: 0.0026423301805066934
# Iteration: 0, Model difference: 17.590983
# Moments errors are: 0.0006984909648568528
# Iteration: 0, Model difference: 17.588046
# Moments errors are: 0.0006928352660474566
# Iteration: 0, Model difference: 17.590268
# Moments errors are: 0.0006958421565047572
# Iteration: 0, Model difference: 17.600142
# Moments errors are: 0.0007194033536060567
# Iteration: 0, Model difference: 7.908498
# Moments errors are: 0.0009626752573251207
# Iteration: 0, Model difference: 17.529474
# Moments errors are: 0.0007003358835245615
# Iteration: 0, Model difference: 17.715526
# Moments errors are: 0.008779416379540364
# Iteration: 0, Model difference: 16.151035
# Moments errors are: 0.0008552880368404907
# Iteration: 0, Model difference: 17.570982
# Moments errors are: 0.0008105965199732445
# Iteration: 0, Model difference: 17.568024
# Moments errors are: 0.0009910498725572326
# Iteration: 0, Model difference: 17.570289
# Moments errors are: 0.0008171569930051155
# Iteration: 0, Model difference: 17.580161
# Moments errors are: 0.00076011534720028
# Iteration: 0, Model difference: 7.877150
# Moments errors are: 0.0007775653321133362
# Iteration: 0, Model difference: 17.509515
# Moments errors are: 0.0009640622495840972
# Iteration: 0, Model difference: 17.695666
# Moments errors are: 0.006748560589195079
# Iteration: 0, Model difference: 16.134297
# Moments errors are: 0.0007610108686528317
# Iteration: 0, Model difference: 16.873590
# Moments errors are: 0.007896182860710291
# Iteration: 0, Model difference: 16.870434
# Moments errors are: 0.007627158773666172
# Iteration: 0, Model difference: 16.873275
# Moments errors are: 0.007567829002340713
# Iteration: 0, Model difference: 16.882694
# Moments errors are: 0.007860870660896128
# Iteration: 0, Model difference: 7.113262
# Moments errors are: 0.007557566639261598
# Iteration: 0, Model difference: 16.814154
# Moments errors are: 0.007562512328558825
# Iteration: 0, Model difference: 16.999013
# Moments errors are: 0.0011973869757092232
# Iteration: 0, Model difference: 15.501970
# Moments errors are: 0.007562680634523279
# Iteration: 0, Model difference: 17.508010
# Moments errors are: 0.000979264297237761
# Iteration: 0, Model difference: 17.505035
# Moments errors are: 0.0009365274610808581
# Iteration: 0, Model difference: 17.507351
# Moments errors are: 0.0009299927924559508
# Iteration: 0, Model difference: 17.517182
# Moments errors are: 0.0010419618203786904
# Iteration: 0, Model difference: 7.808194
# Moments errors are: 0.001048547135191615
# Iteration: 0, Model difference: 17.446727
# Moments errors are: 0.002221076444064932
# Iteration: 0, Model difference: 17.632761
# Moments errors are: 0.006815905617222418
# Iteration: 0, Model difference: 16.077237
# Moments errors are: 0.0010582918717191958
# Iteration: 0, Model difference: 17.562579
# Moments errors are: 0.0009335853875780064
# Iteration: 0, Model difference: 17.559619
# Moments errors are: 0.0007882524792302293
# Iteration: 0, Model difference: 17.561891
# Moments errors are: 0.000812550532243435
# Iteration: 0, Model difference: 17.571758
# Moments errors are: 0.0007946892470205792
# Iteration: 0, Model difference: 7.867949
# Moments errors are: 0.0010239514820474323
# Iteration: 0, Model difference: 17.501137
# Moments errors are: 0.0007786537768895155
# Iteration: 0, Model difference: 17.687273
# Moments errors are: 0.006123246574098324
# Iteration: 0, Model difference: 16.126684
# Moments errors are: 0.0007786186507119242
# Iteration: 0, Model difference: 17.570543
# Moments errors are: 0.0008523331525028559
# Iteration: 0, Model difference: 17.567586
# Moments errors are: 0.0008324248674834835
# Iteration: 0, Model difference: 17.569851
# Moments errors are: 0.0009043028552571421
# Iteration: 0, Model difference: 17.579723
# Moments errors are: 0.000988692922511752
# Iteration: 0, Model difference: 7.876670
# Moments errors are: 0.0007830752854431628
# Iteration: 0, Model difference: 17.509078
# Moments errors are: 0.0008096653096445036
# Iteration: 0, Model difference: 17.695228
# Moments errors are: 0.005913120022115931
# Iteration: 0, Model difference: 16.133900
# Moments errors are: 0.0007708968719632914
# Iteration: 0, Model difference: 17.570977
# Moments errors are: 0.000779662760913876
# Iteration: 0, Model difference: 17.568019
# Moments errors are: 0.00076362761405628
# Iteration: 0, Model difference: 17.570285
# Moments errors are: 0.0008724649492410535
# Iteration: 0, Model difference: 17.580157
# Moments errors are: 0.0007682837295497854
# Iteration: 0, Model difference: 7.877145
# Moments errors are: 0.0009186961144671345
# Iteration: 0, Model difference: 17.509511
# Moments errors are: 0.0008138293382590501
# Iteration: 0, Model difference: 17.695662
# Moments errors are: 0.006923765186133082
# Iteration: 0, Model difference: 16.134293
# Moments errors are: 0.0007626822065130939
# Iteration: 0, Model difference: 17.570975
# Moments errors are: 0.0008987658219862083
# Iteration: 0, Model difference: 17.568017
# Moments errors are: 0.0007601802273127325
# Iteration: 0, Model difference: 17.570282
# Moments errors are: 0.0007618892786170842
# Iteration: 0, Model difference: 17.580154
# Moments errors are: 0.000823021757626856
# Iteration: 0, Model difference: 7.877142
# Moments errors are: 0.0010550931705572265
# Iteration: 0, Model difference: 17.509508
# Moments errors are: 0.0007902464771890893
# Iteration: 0, Model difference: 17.695659

# %%
results1_2
# Out:
#       fun: 0.0009172056112549222
#  hess_inv: <7x7 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.00018294, -0.00146537,  0.00012174,  0.00087829,  0.00141824,
#         0.06196424,  0.0014405 ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 200
#       nit: 6
#      njev: 25
#    status: 0
#   success: True
#         x: array([-2.24648901,  0.32716889,  0.41296885,  0.19433193, 29.97242835,
#         0.18486076,  0.22302292])

# %%
    params_init_1 = np.array([-2.2067, 0.8349, 0.3594, 0.044, 29.966, 0.381, 0.182])
    mu, rho, sigma, delta, gamma, theta, lambda_ = params_init_1
    fv = FirmValue(delta=delta, mu=mu, rho=rho, sigma=sigma, theta=theta, lambda_=lambda_, gamma=gamma)
    error_code = fv.optimize_terry()
# Out:
# Iteration: 0, Model difference: 3.130944
# Iteration: 10, Model difference: 0.308268

# %%
    data_moments = np.array([0.1885677166674841, 0.0285271524764669, 0.0768111297195329, 0.0032904184631855, 
                             0.0012114713963756, 0.0058249053810193, 0.1421154126428439, 0.0080642043112130])
    sim_moments = get_moments(fv, 1)
    moments_error = get_moments_error(data_moments, sim_moments, cov_matrix)

# %%
sim_moments
